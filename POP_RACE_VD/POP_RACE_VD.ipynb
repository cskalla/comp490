# %%
import pandas as pd
df = pd.read_csv ('Race_Hispanic_Not_Data.csv')
#load in demographic data from csv file  
with open('Race_Hispanic_Not_Data.csv', 'r') as f:race = pd.read_csv(f, header=0)
print(df)
# Out:
#                    GEO_ID                                               NAME  \
# 0                      id                               Geographic Area Name
# 1    7000000US220890001-1                 1-1, St. Charles Parish, Louisiana
# 2    7000000US220890001-2                 1-2, St. Charles Parish, Louisiana
# 3    7000000US220890001-3                 1-3, St. Charles Parish, Louisiana
# 4    7000000US220890001-5                 1-5, St. Charles Parish, Louisiana
# ..                    ...                                                ...
# 905  7000000US220950007-5        7-5, St. John the Baptist Parish, Louisiana
# 906  7000000US220950007-7        7-7, St. John the Baptist Parish, Louisiana
# 907  7000000US22095004-13       4-13, St. John the Baptist Parish, Louisiana
# 908  7000000US22095004-14       4-14, St. John the Baptist Parish, Louisiana
# 909  7000000US22095ZZZZZZ  Voting Districts Not Defined, St. John the Bap...
#
# ...

# %%
#write a script that will take column 6 and put it into its own array
print(df.iloc[0][6])
print(len(df)-1)
ids = []
values = []
for val in range(84, 436):
    precinct = df.loc[val]['NAME']
    values.append(df.loc[val]['P2_005N'])
    ids.append(precinct.split(',')[0])
print(ids)
print(values)
# Out:
#  !!Total:!!Not Hispanic or Latino:!!Population of one race:!!White alone
# 909
# ...
