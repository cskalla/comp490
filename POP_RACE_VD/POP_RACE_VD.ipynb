# %%
import pandas as pd
df = pd.read_csv ('DECENNIALPL2020.P1_data_with_overlays_2021-10-21T093327.csv')
#load in demographic data from csv file  
with open('DECENNIALPL2020.P1_data_with_overlays_2021-10-21T093327.csv', 'r') as f:race = pd.read_csv(f, header=0)
print(df)
# Out:
#                    GEO_ID                                               NAME  \
# 0                      id                               Geographic Area Name
# 1    7000000US22051000001                     1, Jefferson Parish, Louisiana
# 2    7000000US22051000002                     2, Jefferson Parish, Louisiana
# 3    7000000US22051000003                     3, Jefferson Parish, Louisiana
# 4    7000000US22051000004                     4, Jefferson Parish, Louisiana
# ..                    ...                                                ...
# 905  7000000US22103000S22                 S22, St. Tammany Parish, Louisiana
# 906  7000000US22103000S23                 S23, St. Tammany Parish, Louisiana
# 907  7000000US22103000S24                 S24, St. Tammany Parish, Louisiana
# 908  7000000US22103000S25                 S25, St. Tammany Parish, Louisiana
# 909  7000000US22103ZZZZZZ  Voting Districts Not Defined, St. Tammany Pari...
#
# ...

# %%
#write a script that will take column
