# %%
import pandas as pd
df = pd.read_csv ('RACE.csv')
#load in demographic data from csv file  
with open('RACE.csv', 'r') as f:race = pd.read_csv(f, header=0)
print(df)
# Out:
#                    GEO_ID                                               NAME  \
# 0                      id                               Geographic Area Name
# 1    7000000US220710001-1            Precinct 1-1, Orleans Parish, Louisiana
# 2    7000000US220710001-2            Precinct 1-2, Orleans Parish, Louisiana
# 3    7000000US220710001-5            Precinct 1-5, Orleans Parish, Louisiana
# 4    7000000US220710001-6            Precinct 1-6, Orleans Parish, Louisiana
# ..                    ...                                                ...
# 363  7000000US220710009-7            Precinct 9-7, Orleans Parish, Louisiana
# 364  7000000US220710009-8            Precinct 9-8, Orleans Parish, Louisiana
# 365  7000000US22071009-8A           Precinct 9-8A, Orleans Parish, Louisiana
# 366  7000000US220710009-9            Precinct 9-9, Orleans Parish, Louisiana
# 367  7000000US22071ZZZZZZ  Voting Districts not defined, Orleans Parish, ...
#
#                                                P002050  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002051  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002052  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002053  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002054  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002055  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002056  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002057  ...  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...  ...
# 1                                                    0  ...
# 2                                                    0  ...
# 3                                                    0  ...
# 4                                                    0  ...
# ..                                                 ...  ...
# 363                                                  0  ...
# 364                                                  0  ...
# 365                                                  0  ...
# 366                                                  0  ...
# 367                                                  0  ...
#
#                                                P002039  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002040  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002041  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002042  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002043  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002044  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002045  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002046  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002047  \
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
#                                                P002048
# 0    Total!!Not Hispanic or Latino!!Two or More Rac...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 363                                                  0
# 364                                                  0
# 365                                                  0
# 366                                                  0
# 367                                                  0
#
# [368 rows x 75 columns]

# %%
#write a script that will take column 6 and put it into its own array
print(df.iloc[0][6])
print(len(df)-1)
ids = []
values = []
for val in range(84, 436):
    precinct = df.loc[val]['NAME']
    values.append(df.loc[val]['P2_005N'])
    ids.append(precinct.split(',')[0])
print(ids)
print(values)
# Out:
# Total!!Not Hispanic or Latino!!Two or More Races!!Population of four races!!White; Black or African American; Asian; Some Other Race
# 367
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\comp484\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\comp484\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\comp484\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'P2_005N'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14900/2424338834.py in <module>
#       6 for val in range(84, 436):
#       7     precinct = df.loc[val]['NAME']
# ----> 8     values.append(df.loc[val]['P2_005N'])
#       9     ids.append(precinct.split(',')[0])
#      10 print(ids)
#
# ~\anaconda3\envs\comp484\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\envs\comp484\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\envs\comp484\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'P2_005N'
