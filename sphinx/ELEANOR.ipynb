# %%
import pandas as pd
df = pd.read_csv ('RACE.csv')
hf = pd.read_csv ('INCOME.csv')
#load in demographic data from csv file  
with open('RACE.csv', 'r') as f:race = pd.read_csv(f, header=0)
with open('INCOME.csv', 'r') as f:race = pd.read_csv(f, header=0)
#print(df)
print(hf)
# Out:
#              GEO_ID                                               NAME  \
# 0                id                               Geographic Area Name
# 1    620L200US22001           State House District 1 (2010), Louisiana
# 2    620L200US22002           State House District 2 (2010), Louisiana
# 3    620L200US22003           State House District 3 (2010), Louisiana
# 4    620L200US22004           State House District 4 (2010), Louisiana
# ..              ...                                                ...
# 102  620L200US22102         State House District 102 (2010), Louisiana
# 103  620L200US22103         State House District 103 (2010), Louisiana
# 104  620L200US22104         State House District 104 (2010), Louisiana
# 105  620L200US22105         State House District 105 (2010), Louisiana
# 106  620L200US22ZZZ  State House Districts not defined (2010), Loui...
#
#                   S1903_C01_001E                      S1903_C01_001M  \
# 0    Total!!Estimate!!Households  Total!!Margin of Error!!Households
# 1                          17584                                 595
# 2                          13391                                 501
# 3                          13829                                 457
# 4                          15974                                 457
# ..                           ...                                 ...
# 102                        12515                                 516
# 103                         6943                                 394
# 104                         5805                                 368
# 105                        12925                                 500
# 106                            0                                 123
#
#                        S1903_C01_002E  \
# 0    Total!!Estimate!!One race!!White
# 1                                74.3
# 2                                25.6
# 3                                10.4
# 4                                28.8
# ..                                ...
# 102                              28.8
# 103                              62.2
# 104                              75.0
# 105                              83.0
# 106                                 -
#
#                               S1903_C01_002M  \
# 0    Total!!Margin of Error!!One race!!White
# 1                                        1.7
# 2                                        2.2
# 3                                        1.3
# 4                                        1.8
# ..                                       ...
# 102                                      1.8
# 103                                      3.5
# 104                                      3.3
# 105                                      2.0
# 106                                       **
#
#                                         S1903_C01_003E  \
# 0    Total!!Estimate!!One race!!Black or African Am...
# 1                                                 24.2
# 2                                                 71.0
# 3                                                 87.6
# 4                                                 68.3
# ..                                                 ...
# 102                                               66.9
# 103                                               18.2
# 104                                               19.6
# 105                                               13.0
# 106                                                  -
#
#                                         S1903_C01_003M  \
# 0    Total!!Margin of Error!!One race!!Black or Afr...
# 1                                                  1.6
# 2                                                  2.2
# 3                                                  1.4
# 4                                                  1.7
# ..                                                 ...
# 102                                                1.8
# 103                                                2.5
# 104                                                2.7
# 105                                                2.0
# 106                                                 **
#
#                                         S1903_C01_004E  \
# 0    Total!!Estimate!!One race!!American Indian and...
# 1                                                  0.5
# 2                                                  0.2
# 3                                                  0.4
# 4                                                  0.2
# ..                                                 ...
# 102                                                0.2
# 103                                                0.7
# 104                                                1.1
# 105                                                1.4
# 106                                                  -
#
#                                         S1903_C01_004M  ...  \
# 0    Total!!Margin of Error!!One race!!American Ind...  ...
# 1                                                  0.3  ...
# 2                                                  0.2  ...
# 3                                                  0.4  ...
# 4                                                  0.3  ...
# ..                                                 ...  ...
# 102                                                0.3  ...
# 103                                                0.7  ...
# 104                                                1.1  ...
# 105                                                0.5  ...
# 106                                                 **  ...
#
#                                         S1903_C02_027E  \
# 0    Median income (dollars)!!Estimate!!NONFAMILY H...
# 1                                                24917
# 2                                                17538
# 3                                                17422
# 4                                                20555
# ..                                                 ...
# 102                                              20550
# 103                                              26734
# 104                                              20130
# 105                                              29098
# 106                                                  -
#
#                                         S1903_C02_027M  \
# 0    Median income (dollars)!!Margin of Error!!NONF...
# 1                                                 5210
# 2                                                 3077
# 3                                                 5022
# 4                                                 4577
# ..                                                 ...
# 102                                               5539
# 103                                               9861
# 104                                               3431
# 105                                               9081
# 106                                                 **
#
#                                         S1903_C02_028E  \
# 0    Median income (dollars)!!Estimate!!NONFAMILY H...
# 1                                                47949
# 2                                                29750
# 3                                                22215
# 4                                                33250
# ..                                                 ...
# 102                                              49444
# 103                                              42717
# 104                                              48875
# 105                                              70707
# 106                                                  -
#
#                                         S1903_C02_028M  \
# 0    Median income (dollars)!!Margin of Error!!NONF...
# 1                                                 9395
# 2                                                17847
# 3                                                15361
# 4                                                23518
# ..                                                 ...
# 102                                              13076
# 103                                              29607
# 104                                              47483
# 105                                               8057
# 106                                                 **
#
#                                         S1903_C02_029E  \
# 0    Median income (dollars)!!Estimate!!PERCENT IMP...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 102                                                (X)
# 103                                                (X)
# 104                                                (X)
# 105                                                (X)
# 106                                                (X)
#
#                                         S1903_C02_029M  \
# 0    Median income (dollars)!!Margin of Error!!PERC...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 102                                                (X)
# 103                                                (X)
# 104                                                (X)
# 105                                                (X)
# 106                                                (X)
#
#                                         S1903_C02_030E  \
# 0    Median income (dollars)!!Estimate!!PERCENT IMP...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 102                                                (X)
# 103                                                (X)
# 104                                                (X)
# 105                                                (X)
# 106                                                (X)
#
#                                         S1903_C02_030M  \
# 0    Median income (dollars)!!Margin of Error!!PERC...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 102                                                (X)
# 103                                                (X)
# 104                                                (X)
# 105                                                (X)
# 106                                                (X)
#
#                                         S1903_C02_031E  \
# 0    Median income (dollars)!!Estimate!!PERCENT IMP...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 102                                                (X)
# 103                                                (X)
# 104                                                (X)
# 105                                                (X)
# 106                                                (X)
#
#                                         S1903_C02_031M
# 0    Median income (dollars)!!Margin of Error!!PERC...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 102                                                (X)
# 103                                                (X)
# 104                                                (X)
# 105                                                (X)
# 106                                                (X)
#
# [107 rows x 122 columns]

# %%
#write a script that will take column 6 and put it into its own array
print(df.iloc[0][6])
print(len(df)-1)
ids = []
values = []
for val in range(1,len(df)-1):
    precinct = df.loc[val]['NAME']
    values.append(df.loc[val]['P002005'])
    ids.append(precinct.split(' ')[1].replace(',', ''))
#print(ids)
#print(values)
# Out:
# Total!!Not Hispanic or Latino!!Two or More Races!!Population of four races!!White; Black or African American; Asian; Some Other Race
# 367
# ['1-1', '1-2', '1-5', '1-6', '10-11', '10-12', '10-13', '10-14', '10-3', '10-6', '10-7', '10-8', '10-9', '11-10', '11-11', '11-12', '11-13', '11-14', '11-17', '11-2', '11-3', '11-4', '11-5', '11-8', '11-9', '12-1', '12-10', '12-11', '12-12', '12-13', '12-14', '12-16', '12-17', '12-19', '12-2', '12-3', '12-4', '12-5', '12-6', '12-7', '12-8', '12-9', '13-1', '13-10', '13-11', '13-12', '13-13', '13-14', '13-15', '13-16', '13-2', '13-3', '13-4', '13-5', '13-6', '13-7', '13-8', '13-9', '14-1', '14-10', '14-11', '14-12', '14-13A', '14-14', '14-15', '14-16', '14-17', '14-18A', '14-19', '14-2', '14-20', '14-21', '14-23', '14-24A', '14-25', '14-26', '